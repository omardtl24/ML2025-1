# %% [markdown]
# # Test Quiz
# ------------------
# This quiz aims to introduce you to [UNCode](https://uncode.unal.edu.co/). The automatic online Judge of Universidad Nacional de Colombia.
#
# This platform is going to be used throughout the course to automatically grade some quices and assignments. You will be allowed to upload and submit Jupyter Notebooks.
#
# Below are the different given problems. Please **do not change the signature of the functions to implement**.
#
# Once you are done with the solution, save this notebook to your computer and  submit it through [UNCode](https://uncode.unal.edu.co/).

# %% [markdown]
# ### Problem 1
# Implement the function `calculate_vector_norm` that receives a vector as a tuple and return a float containing the norm of the vector.
# For example:
#
# ```python
# >> calculate_norm_vector((2, -2, 3, -4))
# 5.7445626
# ```

# %%
import numpy as np

def calculate_norm_vector(vector):
    """
    Function that calculates the norm of a vector
    Args:
    - vector (tuple): the vector used to calculate the norm.
    return:
    float containing the norm of the vector.
    """
    # Your code here
    return np.linalg.norm(vector)

# %%
calculate_norm_vector((2, -2, 3, -4))
# Out:
# 5.744562646538029
